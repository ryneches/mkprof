# %% [raw]
# title: A Simple Test Post
# date: 2025-03-01
# authors:
#   - testauthor
# tags:
#   - testing

# %% [markdown]
# # A Simple Test Post
#
# This is a test post with enough content to trigger the automatic excerpt marker insertion.

# %%
print('hello world')
# Out:
# hello world
