# %% [raw]
# title: HTML Image Test
# date: 2025-03-02
# authors:
#   - testauthor

# %% [markdown]
# # HTML Image Test
#
# <img src="assets/diagram.svg" alt="A diagram" width="600" />
#
# And a markdown image: ![logo](assets/logo.png)
#
# And an external image: ![external](https://example.com/img.png)
